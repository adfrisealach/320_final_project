# %%
import pandas as pd

# %%
df = pd.read_clipboard()
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# /tmp/ipykernel_1411118/781972871.py in <module>
# ----> 1 df = pd.read_clipboard()
#
# ~/miniconda3/envs/ds_core/lib/python3.9/site-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      39     from pandas.io.parsers import read_csv
#      40
# ---> 41     text = clipboard_get()
#      42
#      43     # Try to decode (if needed, as "text" might already be a string here).
#
# ~/miniconda3/envs/ds_core/lib/python3.9/site-packages/pandas/io/clipboard/__init__.py in lazy_load_stub_paste()
#     653     global copy, paste
#     654     copy, paste = determine_clipboard()
# --> 655     return paste()
#     656
#     657
#
# ~/miniconda3/envs/ds_core/lib/python3.9/site-packages/pandas/io/clipboard/__init__.py in __call__(self, *args, **kwargs)
#     292     class ClipboardUnavailable:
# ...
